# %%
# %matplotlib inline
import quantstats as qs
import numpy as np
import datetime as dt

# extend pandas functionality with metrics, etc.
qs.extend_pandas()

# Create random return data with a date index.
np.random.seed(42)
index = pd.date_range(end=dt.datetime.now(), periods=1000, freq='B')
stock = pd.Series(np.random.normal(0.001, 0.02, len(index)), index=index)

# show sharpe ratio
qs.stats.sharpe(stock)
# Out:
# np.float64(1.1239729896454933)

# %%
# 现在可以正常生成快照图
qs.plots.snapshot(stock, title='synthetic data', show=True)

# %%
np.random.seed(42)
benchmark = pd.Series(np.random.normal(0.0, 0.02, len(index)), index=index)

qs.reports.full(stock, benchmark, output="/tmp/report.html")
# Out:
# <h4>Performance Metrics</h4>
#                            Benchmark          Strategy
# -------------------------  -----------------  -----------------
# Start Period               2021-09-22         2021-09-22
# End Period                 2025-07-22         2025-07-22
# Risk-Free Rate             0.0%               0.0%
# Time in Market             100.0%             100.0%
#
# Cumulative Return          21.57%             230.29%
# CAGR﹪                     3.58%              24.01%
#
# Sharpe                     0.31               1.12
# Prob. Sharpe Ratio         73.39%             98.77%
# Smart Sharpe               0.31               1.12
# Sortino                    0.46               1.71
# Smart Sortino              0.45               1.7
# Sortino/√2                 0.32               1.21
# Smart Sortino/√2           0.32               1.2
# Omega                      1.19               1.19
#
# Max Drawdown               -50.97%            -33.99%
# Longest DD Days            675                554
# Volatility (ann.)          31.09%             31.09%
# R^2                        1.0                1.0
# Information Ratio          691192703263857.6  691192703263857.6
# Calmar                     0.07               0.71
# Skew                       0.12               0.12
# Kurtosis                   0.07               0.07
#
# Expected Daily %           0.02%              0.12%
# Expected Monthly %         0.42%              2.57%
# Expected Yearly %          3.98%              26.99%
# Kelly Criterion            0.17%              10.56%
# Risk of Ruin               0.0%               0.0%
# Daily Value-at-Risk        -3.18%             -3.08%
# Expected Shortfall (cVaR)  -3.18%             -3.08%
#
# Max Consecutive Wins       9                  9
# Max Consecutive Losses     8                  7
# Gain/Pain Ratio            0.05               0.19
# Gain/Pain (1M)             0.25               1.3
#
# Payoff Ratio               0.96               1.09
# Profit Factor              1.05               1.19
# Common Sense Ratio         1.15               1.4
# CPC Index                  0.52               0.7
# Tail Ratio                 1.1                1.17
# Outlier Win Ratio          2.99               2.93
# Outlier Loss Ratio         2.65               2.7
#
# MTD                        -1.44%             0.15%
# 3M                         -4.2%              2.34%
# 6M                         32.53%             50.88%
# YTD                        41.62%             63.66%
# 1Y                         69.79%             120.51%
# 3Y (ann.)                  6.23%              27.2%
# 5Y (ann.)                  3.58%              24.01%
# 10Y (ann.)                 3.58%              24.01%
# All-time (ann.)            3.58%              24.01%
#
# Best Day                   7.71%              7.81%
# Worst Day                  -6.48%             -6.38%
# Best Month                 31.11%             33.72%
# Worst Month                -15.77%            -13.97%
# Best Year                  41.62%             63.66%
# Worst Year                 -27.6%             -8.62%
#
# Avg. Drawdown              -8.76%             -5.14%
# Avg. Drawdown Days         85                 35
# Recovery Factor            0.76               4.08
# Ulcer Index                0.27               0.16
# Serenity Index             0.06               0.6
#
# Avg. Up Month              8.39%              10.67%
# Avg. Down Month            -8.07%             -6.05%
# Win Days %                 51.0%              53.3%
# Win Month %                48.94%             61.7%
# Win Quarter %              52.94%             58.82%
# Win Year %                 60.0%              60.0%
#
# Beta                       -                  1.0
# Alpha                      -                  0.25
# Correlation                -                  100.0%
# Treynor Ratio              -                  230.29%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2023-05-16  2023-11-28  2024-11-19   554    -33.986855        -33.586362
# 2  2021-10-06  2021-12-03  2022-07-11   279    -25.506838        -24.615973
# 3  2025-06-10  2025-07-16  2025-07-22    43    -17.444750        -17.061407
# 4  2022-09-21  2022-10-03  2022-11-30    71    -12.589336        -12.350562
# 5  2022-12-29  2023-01-24  2023-02-24    58    -11.262716        -10.971688
# <h4>Strategy Visualization</h4>
